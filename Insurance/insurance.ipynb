# %% [markdown]
# # Some linear regression

# %% [markdown]
# data from https://www.kaggle.com/mirichoi0218/insurance

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model
from scipy import stats

# %%
data = pd.read_csv("insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
p = sns.scatterplot(x = data["bmi"], y = data["charges"], data = data, color = "blue")
p.set_title("bmi vs charges")
_ = plt.set_xticklabels(plt.get_xticklabels())

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(data['bmi'],data['charges'])

# %%
ax = sns.regplot(x="bmi", y="charges", data=data, color='b', 
 line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope,intercept)})

# %% [markdown]
# seems like linear regression wasn't too helpful
